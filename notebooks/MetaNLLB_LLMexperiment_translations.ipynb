# %% [markdown]
# #Background
#
# Author: Christian Resch
# Date: January 2024
#
# Google Colab to use 600m NLLB model to translate benchmark datasets to test various LLMs for Swahili, Gikuyu, Hindi and Bhojpuri.
#
# Set up as in this [medium blog post](https://medium.com/@perezogayo/translating-text-using-meta-ais-nllb-fb189f3a946c).

# %% [markdown]
# #1 Set up NLLB

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

tokenizer = AutoTokenizer.from_pretrained('facebook/nllb-200-distilled-600M')
model = AutoModelForSeq2SeqLM.from_pretrained('facebook/nllb-200-distilled-600M')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.55k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %% [markdown]
# #2 Set up pipelines

# %%
#Set up pipelines

# Swahili translator
#translator_en_swh = pipeline('translation', model=model, tokenizer=tokenizer, src_lang='eng_Latn', tgt_lang='swh_Latn', max_length = 200)

# Kikuyu translator
translator_en_kik = pipeline('translation', model=model, tokenizer=tokenizer, src_lang='eng_Latn', tgt_lang='kik_Latn', max_length = 200)

# Bhojpuri translator
translator_en_luo = pipeline('translation', model=model, tokenizer=tokenizer, src_lang='eng_Latn', tgt_lang='luo_Latn', max_length = 200)

# Hindi translator
#translator_en_hin = pipeline('translation', model=model, tokenizer=tokenizer, src_lang='eng_Latn', tgt_lang='hin_Deva', max_length = 200)

# Bhojpuri translator
#translator_en_bho = pipeline('translation', model=model, tokenizer=tokenizer, src_lang='eng_Latn', tgt_lang='bho_Deva', max_length = 200)

# %% [markdown]
# # 3 Load data

# %%
import os
from google.colab import drive
import json

# %%
drive.mount('/content/drive') # see here for details https://colab.research.google.com/notebooks/io.ipynb#scrollTo=RWSJpsyKqHjH
os.getcwd()
# Out:
# Mounted at /content/drive
# '/content'

# %%
os.chdir('drive/MyDrive/Data/X-CSR_datasets/en')

# %%
ls
# Out:
# dev.jsonl  test.jsonl  train.jsonl

# %%
with open('dev.jsonl') as f:
  en = [json.loads(line) for line in f] # work around needed as dataset is in jsonl format

print("First entry in English dev dataset")
print(en[:2]) #list of dictionaries
print(en[0].keys())

print('en has length: ' + str(len(en)))
# Out:
# First entry in English dev dataset
# [{'id': 'd3845adc08414fda', 'lang': 'en', 'question': {'stem': 'The dental office handled a lot of patients who experienced traumatic mouth injury, where were these patients coming from?', 'choices': [{'label': 'A', 'text': 'town'}, {'label': 'B', 'text': 'michigan'}, {'label': 'C', 'text': 'hospital'}, {'label': 'D', 'text': 'schools'}, {'label': 'E', 'text': 'office building'}]}, 'answerKey': 'C'}, {'id': '35677bbcf00c4e3a', 'lang': 'en', 'question': {'stem': 'Where can you find bald eagles and cheese in the midwest?', 'choices': [{'label': 'A', 'text': 'colorado'}, {'label': 'B', 'text': 'currency'}, {'label': 'C', 'text': 'iowa'}, {'label': 'D', 'text': 'arctic'}, {'label': 'E', 'text': 'wisconsin'}]}, 'answerKey': 'E'}]
# dict_keys(['id', 'lang', 'question', 'answerKey'])
# en has length: 1000

# %% [markdown]
# #4 Translate English-Kikuyu

# %%
#Import further packages
import time

# %%
#Define target language

#tgt_lang = 'kik'
tgt_lang = 'bho'

# %%
#Created directory for new language

path = '/content/drive/MyDrive/Data/X-CSR_datasets/'

if tgt_lang not in os.listdir(path):
  os.mkdir(path + tgt_lang)
  print('Created directory ' + tgt_lang + ' in ' + path +'.')
else:
  print('Directory ' + tgt_lang + ' already exists in ' + path +'.')
# Out:
# Directory bho already exists in /content/drive/MyDrive/Data/X-CSR_datasets/.

# %%
#Set up new dataset

translated_data = []

# %%
#translate
#Not super worked out yet, so you have to replace the translator from above by hand, see comments below

for english_dict in en:
  start_time = time.time()

  translated_dict = {}

  for i in english_dict.keys():
      translated_dict[i] = None

  translated_dict['id'] = english_dict['id']
  translated_dict['lang'] = tgt_lang

  #question is a dictionary with stem: text, choices: list of dictionaries
  question_translated = {}

  stem = english_dict['question']['stem']

  ####
  # INSERT CORRECT TRANSLATOR HERE!
  ####

  #stem_translated = translator_en_bho(stem)
  stem_translated = translator_en_kik(stem)

  question_translated['stem'] = stem_translated[0]['translation_text']

  #translating the choices
  choices = english_dict['question']['choices']

  choices_translated = []

  for choice in choices:
    translated_choice = {}

    translated_choice['label'] = choice['label']

    text = choice['text']

    #####
    # INSERT CORRECT TRANSLATOR HERE!
    #####

    #text_translated = translator_en_bho(text)
    text_translated = translator_en_kik(text)

    translated_choice['text'] = text_translated[0]['translation_text']

    choices_translated.append(translated_choice)

  question_translated['choices'] = choices_translated

  translated_dict['question'] = question_translated

  translated_dict['answerKey'] = english_dict['answerKey']

  translated_data.append(translated_dict)

  end_time = round(time.time() - start_time)
  print('Successfully translated ' + str(translated_dict['id']) + ' from en to ' + tgt_lang + '. Time needed: ' + str(end_time) + ' seconds')

# Serializing json
json_object = json.dumps(translated_data, indent=4)

# Writing to results_sw.json
with open(path + tgt_lang + '/dev.json', "w") as outfile:
    outfile.write(json_object)
# Out:
# Successfully translated d3845adc08414fda from en to bho. Time needed: 11 seconds
# Successfully translated 35677bbcf00c4e3a from en to bho. Time needed: 9 seconds
# Successfully translated 048b0565dc77a993 from en to bho. Time needed: 8 seconds
# Successfully translated cbb8e2554edeed45 from en to bho. Time needed: 12 seconds
# Successfully translated 055e75f54b8e913c from en to bho. Time needed: 9 seconds
# Successfully translated f8876108403b66d6 from en to bho. Time needed: 9 seconds
# Successfully translated 6029c72b4deda756 from en to bho. Time needed: 9 seconds
# Successfully translated a44cdb09ea0f1be1 from en to bho. Time needed: 9 seconds
# Successfully translated 2a7d31879031d457 from en to bho. Time needed: 8 seconds
# Successfully translated 47eb76d3df2644cd from en to bho. Time needed: 9 seconds
# Successfully translated c1eede6bb0f42589 from en to bho. Time needed: 7 seconds
# Successfully translated b8bcb55951e48208 from en to bho. Time needed: 8 seconds
# Successfully translated 53042df5a9772dd7 from en to bho. Time needed: 9 seconds
# Successfully translated d1e378c0e5f178ba from en to bho. Time needed: 8 seconds
# Successfully translated 72792d619ceb61d8 from en to bho. Time needed: 10 seconds
# Successfully translated 1fc4fbb93c6620b6 from en to bho. Time needed: 9 seconds
# Successfully translated a4c7f31e8d50eda2 from en to bho. Time needed: 10 seconds
# Successfully translated f2b095c0972d3d69 from en to bho. Time needed: 7 seconds
# Successfully translated a10628a9c9d5baeb from en to bho. Time needed: 8 seconds
# Successfully translated 12e24ac4fab727d4 from en to bho. Time needed: 7 seconds
# Successfully translated 9339c71ef12d2170 from en to bho. Time needed: 8 seconds
# Successfully translated 118a9169ce929a75 from en to bho. Time needed: 8 seconds
# Successfully translated a77f24a4c2a38159 from en to bho. Time needed: 8 seconds
# Successfully translated e553d8f691ce03b2 from en to bho. Time needed: 7 seconds
# Successfully translated 1727b684a0de89b4 from en to bho. Time needed: 8 seconds
# Successfully translated e9880ae07b1d75b8 from en to bho. Time needed: 7 seconds
# Successfully translated 77400032ae6e5930 from en to bho. Time needed: 9 seconds
# Successfully translated c9bfab545ad8ab4f from en to bho. Time needed: 7 seconds
# Successfully translated 7bc0b616a0b2ecae from en to bho. Time needed: 8 seconds
# Successfully translated 89e493b48086ae55 from en to bho. Time needed: 9 seconds
# Successfully translated 145a5e093f9bcb11 from en to bho. Time needed: 7 seconds
# Successfully translated ed5359b47eaee59a from en to bho. Time needed: 7 seconds
# Successfully translated 3c873022ca583b64 from en to bho. Time needed: 9 seconds
# Successfully translated 962b01e8e85c3ed2 from en to bho. Time needed: 10 seconds
# Successfully translated b12a3e397bab3ac7 from en to bho. Time needed: 9 seconds
# Successfully translated b074057439420033 from en to bho. Time needed: 9 seconds
# Successfully translated 0de47a6121743559 from en to bho. Time needed: 10 seconds
# Successfully translated 6cfaf2658f78cfa6 from en to bho. Time needed: 8 seconds
# Successfully translated 8d1b5739478dd85d from en to bho. Time needed: 9 seconds
# Successfully translated 20eff5d174d9990f from en to bho. Time needed: 8 seconds
# Successfully translated f1b4a28e99035803 from en to bho. Time needed: 9 seconds
# Successfully translated 3b584fa8f370dc12 from en to bho. Time needed: 9 seconds
# Successfully translated 8aa93c8f6c2a7b5e from en to bho. Time needed: 8 seconds
# Successfully translated 3dc8041e532a4426 from en to bho. Time needed: 7 seconds
# Successfully translated f02d5aedd5a46ac5 from en to bho. Time needed: 7 seconds
# Successfully translated 75022fbb3ec7828d from en to bho. Time needed: 8 seconds
# Successfully translated 305a845a3dc5ae94 from en to bho. Time needed: 13 seconds
# Successfully translated b742aa1da1735cbb from en to bho. Time needed: 7 seconds
# Successfully translated bc2bb3962ffaf84e from en to bho. Time needed: 8 seconds
# Successfully translated 8c6022d4d16de3b0 from en to bho. Time needed: 15 seconds
# Successfully translated bd20544b423434e4 from en to bho. Time needed: 9 seconds
# Successfully translated a7fd40aa4a793d8b from en to bho. Time needed: 11 seconds
# Successfully translated 7c8ac45c24859593 from en to bho. Time needed: 9 seconds
# Successfully translated 3ce04fa6acca8d3f from en to bho. Time needed: 10 seconds
# Successfully translated 7f57f6546e46bca4 from en to bho. Time needed: 8 seconds
# Successfully translated 5040a51f57f3a39b from en to bho. Time needed: 10 seconds
# Successfully translated b4bb53c288329150 from en to bho. Time needed: 8 seconds
# Successfully translated b95246f5bf3eae65 from en to bho. Time needed: 10 seconds
# Successfully translated b293b0bccc0f3dd3 from en to bho. Time needed: 9 seconds
# Successfully translated 0fe144fea3df246f from en to bho. Time needed: 13 seconds
# Successfully translated bd6386a255041af2 from en to bho. Time needed: 10 seconds
# Successfully translated d0e66290c08652da from en to bho. Time needed: 8 seconds
# Successfully translated ec9329a924fe3286 from en to bho. Time needed: 8 seconds
# Successfully translated 74a0e3a0a9a1b42f from en to bho. Time needed: 9 seconds
# Successfully translated 06caac8ce4a66a9e from en to bho. Time needed: 13 seconds
# Successfully translated f7851cb5961cbca6 from en to bho. Time needed: 8 seconds
# Successfully translated 8994d5a255ef07d5 from en to bho. Time needed: 10 seconds
# Successfully translated c7e1e5e75548487d from en to bho. Time needed: 8 seconds
# Successfully translated 8f1ebbe3753ee934 from en to bho. Time needed: 7 seconds
# Successfully translated b4d13203e29e3e8a from en to bho. Time needed: 9 seconds
# Successfully translated c7950fd6107d1c94 from en to bho. Time needed: 7 seconds
# Successfully translated bb046f3b58224a70 from en to bho. Time needed: 8 seconds
# Successfully translated 655747ab1184ef62 from en to bho. Time needed: 8 seconds
# Successfully translated 170b5dec70871c81 from en to bho. Time needed: 9 seconds
# Successfully translated e84506d8412ef9f6 from en to bho. Time needed: 8 seconds
# Successfully translated 8c63a1e28058abb8 from en to bho. Time needed: 9 seconds
# Successfully translated 00de1d5f1aa4c775 from en to bho. Time needed: 8 seconds
# Successfully translated 43e9a828e1a5cb62 from en to bho. Time needed: 12 seconds
# Successfully translated d32c8b636f553bf6 from en to bho. Time needed: 8 seconds
# Successfully translated be5344ab43bb0968 from en to bho. Time needed: 9 seconds
# Successfully translated 28bb9f1dd33f6919 from en to bho. Time needed: 11 seconds
# Successfully translated 07b394da3f2e4265 from en to bho. Time needed: 8 seconds
# Successfully translated 4d5783a92d8a7ade from en to bho. Time needed: 10 seconds
# Successfully translated 0cfa69c25e81e7d2 from en to bho. Time needed: 11 seconds
# Successfully translated d47873fb5af0a491 from en to bho. Time needed: 8 seconds
# Successfully translated f4547f1c1d2f56b0 from en to bho. Time needed: 9 seconds
# Successfully translated 43cd206a900ba57b from en to bho. Time needed: 10 seconds
# Successfully translated ec31b3c03da094e9 from en to bho. Time needed: 7 seconds
# Successfully translated fa0c81a5b901881d from en to bho. Time needed: 8 seconds
# Successfully translated 2052ab7fc92ca6a9 from en to bho. Time needed: 11 seconds
# Successfully translated a09623c01a245ee5 from en to bho. Time needed: 8 seconds
# Successfully translated 139097eee0f79212 from en to bho. Time needed: 9 seconds
# Successfully translated dc60a544cea0e88e from en to bho. Time needed: 8 seconds
# Successfully translated cc776a35c7b3a5bf from en to bho. Time needed: 7 seconds
# Successfully translated cff7bbee1882f8b4 from en to bho. Time needed: 8 seconds
# Successfully translated 1091884c4077088a from en to bho. Time needed: 11 seconds
# Successfully translated 86762c703e0b8dd2 from en to bho. Time needed: 10 seconds
# Successfully translated ccf01ad78645681f from en to bho. Time needed: 8 seconds
# Successfully translated d77313ba1ca5dbc4 from en to bho. Time needed: 10 seconds
# Successfully translated 4f6156bee1273027 from en to bho. Time needed: 7 seconds
# Successfully translated 9db4f86023b2ee2f from en to bho. Time needed: 8 seconds
# Successfully translated 9c8d3482b4d5acaa from en to bho. Time needed: 9 seconds
# Successfully translated a170029478f3bc76 from en to bho. Time needed: 9 seconds
# Successfully translated 736425bbaa915bc4 from en to bho. Time needed: 8 seconds
# Successfully translated e92e34107eacd536 from en to bho. Time needed: 10 seconds
# Successfully translated 01f3e170cef1ea22 from en to bho. Time needed: 7 seconds
# Successfully translated 770c562345a84c4c from en to bho. Time needed: 11 seconds
# Successfully translated 55c4c9e8114bfd3f from en to bho. Time needed: 10 seconds
# Successfully translated cd53b6e46424e64f from en to bho. Time needed: 10 seconds
# Successfully translated 6a170448df282027 from en to bho. Time needed: 10 seconds
# Successfully translated 158403cdc49b0385 from en to bho. Time needed: 9 seconds
# Successfully translated f90ad3a5a9b4c868 from en to bho. Time needed: 8 seconds
# Successfully translated 4473621ee2661dd4 from en to bho. Time needed: 9 seconds
# Successfully translated 3805ba003f12f41f from en to bho. Time needed: 10 seconds
# Successfully translated 073bd6d7e5afd837 from en to bho. Time needed: 7 seconds
# Successfully translated 58ef6ead75d44f93 from en to bho. Time needed: 8 seconds
# Successfully translated dff438a120cf63ff from en to bho. Time needed: 7 seconds
# Successfully translated 707afb6f69fdce4f from en to bho. Time needed: 8 seconds
# Successfully translated 912a7ab47a020869 from en to bho. Time needed: 8 seconds
# Successfully translated 49dca231dcce2b48 from en to bho. Time needed: 9 seconds
# Successfully translated 59bfdd766bffc265 from en to bho. Time needed: 12 seconds

# %% [markdown]
# #5 Save translated data

# %%
# Serializing json
json_object = json.dumps(translated_data, indent=4)

# Writing to results_sw.json
with open(path + tgt_lang + '/dev.json', "w") as outfile:
    outfile.write(json_object)
